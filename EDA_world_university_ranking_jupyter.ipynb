# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#33475b; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)

# %% [markdown]
# ## <p style="background-color:#33475b; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:powderblue" data-toggle="popover">Content</a>

# %% [markdown]
# According to the sources, **Exploratory Data Analysis (EDA)** is very important as it helps to understand the underlying patterns, anomalies and relationships in data before moving on to any modeling or hypothesis testing. Often summarizing key features of the data using visual methods, EDA enables data scientists to detect errors, identify outliers and test underlying assumptions. This preliminary analysis is essential for selecting appropriate **modeling techniques** and **feature engineering** strategies. EDA also provides **insights** that can guide further data collection efforts and refine research questions, enabling a more targeted and efficient approach for subsequent analysis. Ultimately, EDA provides a solid foundation for making informed decisions based on data.

# %% [markdown]
# ## Aim of the Notebook

# %% [markdown]
# We obtained data from the source website using APIs and consolidated it into a **.csv file**. However, the extraction process did not consistently yield the desired format, presenting several challenges. These include a significant amount of **missing data, superfluous columns, and rows requiring preprocessing**. Consequently, this notebook will primarily focus on tasks such as **gaining insights** into the data, cleaning it, and performing necessary manipulations.
# The ultimate objective is to prepare the dataset for seamless transferal into the database.

# %% [markdown]
# ## <p style="background-color:#33475b; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:powderblue" data-toggle="popover">Content</a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# Figure&Display options
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (10,6)
#pd.set_option('max_colwidth',200)
#pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# ### <p style="background-color:#33475b; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:5=10px 10px;">Reading Consolidated .csv file </p>

# %%
df = pd.read_csv("world_university_ranking_2024.csv")

# %% [markdown]
# ## <p style="background-color:#33475b; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:powderblue" data-toggle="popover">Content</a>

# %% [markdown]
# ### In this section,
# - The properties of the DataFrame converted dataset such as head, shape, data types will be checked.
# - Will be checked if there are publicate rows and remove them from the dataset.
# - Statistical values of the features will be checked.
# - If necessary, will be renamed the columns for ease of use.
# - Basically will be checked for missing values.

# %%
df.head()
# Out:
#   rank                                   name  number_students  \
# 0    1                   University of Oxford            21750
# 1    2                    Stanford University            14517
# 2    3  Massachusetts Institute of Technology            11085
# 3    4                     Harvard University            20050
# 4    5                University of Cambridge            20565
#
#    student_staff_ratio  intl_students  female_male_ratio  overall_score  \
# 0               10.900         42.000             49.000         98.500
# 1                6.400         23.000             47.000         98.000
# 2                8.000         33.000             41.000         97.900
# 3                9.000         25.000             51.000         97.800
# 4               11.500         38.000             48.000         97.500
#
#    teaching_score  research_score  citations_score  industry_income_score  \
# 0          96.600         100.000           99.000                 98.700
# 1          99.000          97.800           99.600                100.000
# 2          98.600          96.200           99.700                100.000
# 3          97.700          99.900           99.400                 84.200
# 4          95.800         100.000           98.000                 87.900
#
#    international_outlook_score  \
# 0                       97.500
# 1                       87.000
# 2                       93.800
# 3                       90.800
# 4                       97.400
#
#                                              address  street_address  \
# 0  University Offices, Wellington Square, Oxford,...             NaN
# 1  450 Jane Stanford Way, Stanford, California, 9...             NaN
# 2  77 Massachusetts Avenue, Cambridge, Massachuse...             NaN
# 3  Massachusetts Hall, Cambridge, Massachusetts, ...             NaN
# 4  The Old Schools, Trinity Lane, Cambridge, Camb...             NaN
#
#    locality_address  region_address  postcode_address  country_address
# 0               NaN             NaN               NaN              NaN
# 1               NaN             NaN               NaN              NaN
# 2               NaN             NaN               NaN              NaN
# 3               NaN             NaN               NaN              NaN
# 4               NaN             NaN               NaN              NaN

# %%
df.sample()
# Out:
#     rank                     name  number_students  student_staff_ratio  \
# 714  601  Nanjing Tech University            38866               13.500
#
#      intl_students  female_male_ratio  overall_score  teaching_score  \
# 714          3.000                NaN         41.800          21.800
#
#      research_score  citations_score  industry_income_score  \
# 714          16.200           69.100                 68.100
#
#      international_outlook_score  \
# 714                       37.100
#
#                                                address  street_address  \
# 714  No.30 Puzhu Road(S), Nanjing, Jiangsu, 211816,...             NaN
#
#      locality_address  region_address  postcode_address  country_address
# 714               NaN             NaN               NaN              NaN

# %%
df.shape
# Out:
# (2671, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2671 entries, 0 to 2670
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   rank                         2671 non-null   object
#  1   name                         2555 non-null   object
#  2   number_students              2671 non-null   int64
#  3   student_staff_ratio          2671 non-null   float64
#  4   intl_students                2668 non-null   float64
#  5   female_male_ratio            2578 non-null   float64
#  6   overall_score                1907 non-null   float64
#  7   teaching_score               1907 non-null   float64
#  8   research_score               1907 non-null   float64
#  9   citations_score              1907 non-null   float64
#  10  industry_income_score        1907 non-null   float64
#  11  international_outlook_score  1907 non-null   float64
#  12  address                      2477 non-null   object
#  13  street_address               0 non-null      float64
#  14  locality_address             0 non-null      float64
#  15  region_address               0 non-null      float64
#  16  postcode_address             0 non-null      float64
#  17  country_address              0 non-null      float64
# dtypes: float64(14), int64(1), object(3)
# memory usage: 375.7+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        number_students  student_staff_ratio  intl_students  female_male_ratio  \
# count         2671.000             2671.000       2668.000           2578.000
# mean         18367.408               19.134          9.817             50.405
# std          23331.379               13.455         13.497             14.062
# min             25.000                0.300          0.000              0.000
# 25%           6180.500               12.300          1.000             43.000
# 50%          12784.000               16.600          5.000             53.000
# 75%          23970.000               22.500         13.000             59.000
# max         482541.000              333.300        100.000             99.000
#
#        overall_score  teaching_score  research_score  citations_score  \
# count       1907.000        1907.000        1907.000         1907.000
# mean          39.048          29.042          23.406           52.195
# std           15.152          13.963          16.691           25.065
# min           22.700           9.400           4.600            3.400
# 25%           28.200          19.400          11.800           30.400
# 50%           36.900          25.800          17.200           52.400
# 75%           49.000          34.500          29.850           73.250
# max           98.500          99.000         100.000           99.700
#
#        industry_income_score  international_outlook_score  street_address  \
# count               1907.000                     1907.000           0.000
# mean                  47.035                       49.916             NaN
# std                   26.150                       21.843             NaN
# min                   15.600                       16.100             NaN
# 25%                   22.200                       31.950             NaN
# 50%                   41.000                       45.300             NaN
# 75%                   68.150                       65.400             NaN
# max                  100.000                       98.800             NaN
#
#        locality_address  region_address  postcode_address  country_address
# count             0.000           0.000             0.000            0.000
# mean                NaN             NaN               NaN              NaN
# std                 NaN             NaN               NaN              NaN
# min                 NaN             NaN               NaN              NaN
# 25%                 NaN             NaN               NaN              NaN
# 50%                 NaN             NaN               NaN              NaN
# 75%                 NaN             NaN               NaN              NaN
# max                 NaN             NaN               NaN              NaN

# %%
df.columns
# Out:
# Index(['rank', 'name', 'number_students', 'student_staff_ratio',
#        'intl_students', 'female_male_ratio', 'overall_score', 'teaching_score',
#        'research_score', 'citations_score', 'industry_income_score',
#        'international_outlook_score', 'address', 'street_address',
#        'locality_address', 'region_address', 'postcode_address',
#        'country_address'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# rank                              0
# name                            116
# number_students                   0
# student_staff_ratio               0
# intl_students                     3
# female_male_ratio                93
# overall_score                   764
# teaching_score                  764
# research_score                  764
# citations_score                 764
# industry_income_score           764
# international_outlook_score     764
# address                         194
# street_address                 2671
# locality_address               2671
# region_address                 2671
# postcode_address               2671
# country_address                2671
# dtype: int64

# %% [markdown]
# ## Deeply Checking for Columns

# %%
df.columns
# Out:
# Index(['rank', 'name', 'number_students', 'student_staff_ratio',
#        'intl_students', 'female_male_ratio', 'overall_score', 'teaching_score',
#        'research_score', 'citations_score', 'industry_income_score',
#        'international_outlook_score', 'address', 'street_address',
#        'locality_address', 'region_address', 'postcode_address',
#        'country_address'],
#       dtype='object')

# %% [markdown]
# ### <p style="background-color:#33475b; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:5=10px 10px;">Rename and Drop Columns </p>

# %%
df.rename(columns={'name' : 'university_name', 
                   'intl_students' : 'diversity_ratio',
                   'country_address' : 'country'}, inplace=True)

# %%
df.drop(columns=['street_address','locality_address', 'region_address', 'postcode_address'], inplace=True)

# %%
df
# Out:
#           rank                        university_name  number_students  \
# 0            1                   University of Oxford            21750
# 1            2                    Stanford University            14517
# 2            3  Massachusetts Institute of Technology            11085
# 3            4                     Harvard University            20050
# 4            5                University of Cambridge            20565
# ...        ...                                    ...              ...
# 2666  Reporter                       Zarqa University             5881
# 2667  Reporter                     Zhetysu University             4872
# 2668  Reporter  Zhytomyr Polytechnic State University             4454
# 2669  Reporter      Ziane Achour University of Djelfa            31103
# 2670  Reporter                    Ziauddin University             5672
#
#       student_staff_ratio  diversity_ratio  female_male_ratio  overall_score  \
# 0                  10.900           42.000             49.000         98.500
# 1                   6.400           23.000             47.000         98.000
# 2                   8.000           33.000             41.000         97.900
# 3                   9.000           25.000             51.000         97.800
# 4                  11.500           38.000             48.000         97.500
# ...                   ...              ...                ...            ...
# 2666               17.000           35.000             60.000            NaN
# 2667               18.200            0.000             66.000            NaN
# 2668               16.100            1.000             40.000            NaN
# 2669               28.500            0.000             55.000            NaN
# 2670                9.200            0.000             58.000            NaN
#
#       teaching_score  research_score  citations_score  industry_income_score  \
# 0             96.600         100.000           99.000                 98.700
# 1             99.000          97.800           99.600                100.000
# 2             98.600          96.200           99.700                100.000
# 3             97.700          99.900           99.400                 84.200
# 4             95.800         100.000           98.000                 87.900
# ...              ...             ...              ...                    ...
# 2666             NaN             NaN              NaN                    NaN
# 2667             NaN             NaN              NaN                    NaN
# 2668             NaN             NaN              NaN                    NaN
# 2669             NaN             NaN              NaN                    NaN
# 2670             NaN             NaN              NaN                    NaN
#
#       international_outlook_score  \
# 0                          97.500
# 1                          87.000
# 2                          93.800
# 3                          90.800
# 4                          97.400
# ...                           ...
# 2666                          NaN
# 2667                          NaN
# 2668                          NaN
# 2669                          NaN
# 2670                          NaN
#
#                                                 address  country
# 0     University Offices, Wellington Square, Oxford,...      NaN
# 1     450 Jane Stanford Way, Stanford, California, 9...      NaN
# 2     77 Massachusetts Avenue, Cambridge, Massachuse...      NaN
# 3     Massachusetts Hall, Cambridge, Massachusetts, ...      NaN
# 4     The Old Schools, Trinity Lane, Cambridge, Camb...      NaN
# ...                                                 ...      ...
# 2666         15 Zarqa, Zarqa, Zarqa Governorate, Jordan      NaN
# 2667  187a I.Zhansugurov Str., Taldykorgan, 040009, ...      NaN
# 2668     103, Chudnivska str., Zhytomyr, 10005, Ukraine      NaN
# 2669    P.O. Box 3117, Djelfa, Djelfa Province, Algeria      NaN
# 2670  4/B Block 6, Saharah-e-Ghalib, Karachi, Sindh,...      NaN
#
# [2671 rows x 14 columns]

# %% [markdown]
# ### 1.1 'rank'

# %% [markdown]
# ### 1.2 'name'

# %%
df[df['name'].isnull()]
# Out:
#           rank name  number_students  student_staff_ratio  intl_students  \
# 94         =95  NaN            32680                9.600         37.000
# 224        201  NaN             6111               11.600         21.000
# 386        351  NaN            16400               10.000         33.000
# 406        401  NaN            16061                6.600         18.000
# 436        401  NaN            34656               18.600         12.000
# ...        ...  ...              ...                  ...            ...
# 2619  Reporter  NaN             6412               16.600          8.000
# 2624  Reporter  NaN             3831                8.700          8.000
# 2625  Reporter  NaN             7720               14.200         10.000
# 2643  Reporter  NaN             6524                5.900         32.000
# 2662  Reporter  NaN            10900               15.700         10.000
#
#       female_male_ratio  overall_score  teaching_score  research_score  \
# 94               50.000         67.000          87.500          75.200
# 224                 NaN         58.600          63.500          48.800
# 386              42.000         51.000          43.400          31.300
# 406              42.000         49.000          71.700          43.900
# 436                 NaN         49.000          34.400          44.000
# ...                 ...            ...             ...             ...
# 2619             33.000            NaN             NaN             NaN
# 2624             52.000            NaN             NaN             NaN
# 2625             78.000            NaN             NaN             NaN
# 2643             66.000            NaN             NaN             NaN
# 2662             57.000            NaN             NaN             NaN
#
#       citations_score  industry_income_score  international_outlook_score  \
# 94             33.900                 91.100                       73.800
# 224            55.100                 68.600                       72.700
# 386            67.400                 61.600                       65.200
# 406            22.100                 51.700                       59.300
# 436            57.300                 56.500                       51.400
# ...               ...                    ...                          ...
# 2619              NaN                    NaN                          NaN
# 2624              NaN                    NaN                          NaN
# 2625              NaN                    NaN                          NaN
# 2643              NaN                    NaN                          NaN
# 2662              NaN                    NaN                          NaN
#
#      address  street_address  locality_address  region_address  \
# 94       NaN             NaN               NaN             NaN
# 224      NaN             NaN               NaN             NaN
# 386      NaN             NaN               NaN             NaN
# 406      NaN             NaN               NaN             NaN
# 436      NaN             NaN               NaN             NaN
# ...      ...             ...               ...             ...
# 2619     NaN             NaN               NaN             NaN
# 2624     NaN             NaN               NaN             NaN
# 2625     NaN             NaN               NaN             NaN
# 2643     NaN             NaN               NaN             NaN
# 2662     NaN             NaN               NaN             NaN
#
#       postcode_address  country_address
# 94                 NaN              NaN
# 224                NaN              NaN
# 386                NaN              NaN
# 406                NaN              NaN
# 436                NaN              NaN
# ...                ...              ...
# 2619               NaN              NaN
# 2624               NaN              NaN
# 2625               NaN              NaN
# 2643               NaN              NaN
# 2662               NaN              NaN
#
# [116 rows x 18 columns]

# %% [markdown]
# There are a lot NaN lines in "name" column and I was figuring out what was the reason for that. I thought it was occured because of situation among of Ukraine and Russia but the reason was different. After the quick research, I learned that Russian universities were removed from the Times Higher Education (THE) World University Rankings 2024 primarily due to the lack of participation from the universities themselves. In previous years, many Russian institutions opted not to submit the required data for the rankings. This lack of participation has led to their exclusion from the 2024 list.

# %% [markdown]
# I need to change all NaN lines with as "Russia University" in terms of "name" column, and I will evalaute once again in next process.

# %%
df.name = df.name.replace('','Russia University')

# %%
df.name = df.name.fillna("Russia University")

# %%
df["name"].isnull().sum()
# Out:
# 0

# %%
df.iloc[94]
# Out:
# rank                                         =95
# name                           Russia University
# number_students                            32680
# student_staff_ratio                        9.600
# intl_students                             37.000
# female_male_ratio                         50.000
# overall_score                             67.000
# teaching_score                            87.500
# research_score                            75.200
# citations_score                           33.900
# industry_income_score                     91.100
# international_outlook_score               73.800
# address                                      NaN
# street_address                               NaN
# locality_address                             NaN
# region_address                               NaN
# postcode_address                             NaN
# country_address                              NaN
# Name: 94, dtype: object

# %%
df.isna().sum()
# Out:
# rank                              0
# name                              0
# number_students                   0
# student_staff_ratio               0
# intl_students                     3
# female_male_ratio                93
# overall_score                   764
# teaching_score                  764
# research_score                  764
# citations_score                 764
# industry_income_score           764
# international_outlook_score     764
# address                         194
# street_address                 2671
# locality_address               2671
# region_address                 2671
# postcode_address               2671
# country_address                2671
# dtype: int64

# %% [markdown]
# ### 'diversity_ratio'

# %%
df[df['intl_students'].isnull()]
# Out:
#           rank                                             name  \
# 2127  Reporter                  École Normale Supérieure d’Oran
# 2310  Reporter                    Kyoto Koka Women’s University
# 2549  Reporter  University of Sufism and Modern Sciences (USMS)
#
#       number_students  student_staff_ratio  intl_students  female_male_ratio  \
# 2127              626               10.600            NaN             92.000
# 2310             1937               18.300            NaN             10.000
# 2549              646               28.100            NaN             29.000
#
#       overall_score  teaching_score  research_score  citations_score  \
# 2127            NaN             NaN             NaN              NaN
# 2310            NaN             NaN             NaN              NaN
# 2549            NaN             NaN             NaN              NaN
#
#       industry_income_score  international_outlook_score  \
# 2127                    NaN                          NaN
# 2310                    NaN                          NaN
# 2549                    NaN                          NaN
#
#                                                 address  street_address  \
# 2127                                N 24, Oran, Algeria             NaN
# 2310  38 Nishikyogokukadono-cho, Ukyo-ku, Kyoto, 615...             NaN
# 2549                 Bhitshah, Matiari, Sindh, Pakistan             NaN
#
#       locality_address  region_address  postcode_address  country_address
# 2127               NaN             NaN               NaN              NaN
# 2310               NaN             NaN               NaN              NaN
# 2549               NaN             NaN               NaN              NaN

# %%
df.intl_students = df.intl_students.fillna(0)

# %%
df['intl_students'].isnull().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# rank                              0
# name                              0
# number_students                   0
# student_staff_ratio               0
# intl_students                     0
# female_male_ratio                93
# overall_score                   764
# teaching_score                  764
# research_score                  764
# citations_score                 764
# industry_income_score           764
# international_outlook_score     764
# address                         194
# street_address                 2671
# locality_address               2671
# region_address                 2671
# postcode_address               2671
# country_address                2671
# dtype: int64

# %% [markdown]
# ### 'female_male_ratio'

# %%
df.female_male_ratio.isnull().sum()
# Out:
# 93

# %%
df.female_male_ratio.describe()
# Out:
# count   2578.000
# mean      50.405
# std       14.062
# min        0.000
# 25%       43.000
# 50%       53.000
# 75%       59.000
# max       99.000
# Name: female_male_ratio, dtype: float64

# %%
df.female_male_ratio.mean()
# Out:
# 50.40535298681148

# %%
df.female_male_ratio = df.female_male_ratio.fillna(df.female_male_ratio.mean())

# %%
df.female_male_ratio.isnull().sum()
# Out:
# 0

# %%
df.female_male_ratio.describe()
# Out:
# count   2671.000
# mean      50.405
# std       13.815
# min        0.000
# 25%       44.000
# 50%       52.000
# 75%       59.000
# max       99.000
# Name: female_male_ratio, dtype: float64

# %%
df.isna().sum()
# Out:
# rank                              0
# name                              0
# number_students                   0
# student_staff_ratio               0
# intl_students                     0
# female_male_ratio                 0
# overall_score                   764
# teaching_score                  764
# research_score                  764
# citations_score                 764
# industry_income_score           764
# international_outlook_score     764
# address                         194
# street_address                 2671
# locality_address               2671
# region_address                 2671
# postcode_address               2671
# country_address                2671
# dtype: int64

# %% [markdown]
# ### 'overall_score'

# %%
df[(df["rank"] == 'Reporter') & (df["overall_score"].isnull())]
# Out:
#           rank                                             name  \
# 1907  Reporter      Abai Kazakh National Pedagogical University
# 1908  Reporter           Abbes Laghrour University of Khenchala
# 1909  Reporter  Abbottabad University of Science and Technology
# 1910  Reporter    Abdelhafid Boussouf University Center of Mila
# 1911  Reporter                          Abdullah Gül University
# ...        ...                                              ...
# 2666  Reporter                                 Zarqa University
# 2667  Reporter                               Zhetysu University
# 2668  Reporter            Zhytomyr Polytechnic State University
# 2669  Reporter                Ziane Achour University of Djelfa
# 2670  Reporter                              Ziauddin University
#
#       number_students  student_staff_ratio  intl_students  female_male_ratio  \
# 1907            16862               16.100          3.000             59.000
# 1908            18085               26.100          0.000             70.000
# 1909             4200               13.300          0.000             31.000
# 1910            11027               24.900          0.000             72.000
# 1911             2944               22.500          9.000             46.000
# ...               ...                  ...            ...                ...
# 2666             5881               17.000         35.000             60.000
# 2667             4872               18.200          0.000             66.000
# 2668             4454               16.100          1.000             40.000
# 2669            31103               28.500          0.000             55.000
# 2670             5672                9.200          0.000             58.000
#
#       overall_score  teaching_score  research_score  citations_score  \
# 1907            NaN             NaN             NaN              NaN
# 1908            NaN             NaN             NaN              NaN
# 1909            NaN             NaN             NaN              NaN
# 1910            NaN             NaN             NaN              NaN
# 1911            NaN             NaN             NaN              NaN
# ...             ...             ...             ...              ...
# 2666            NaN             NaN             NaN              NaN
# 2667            NaN             NaN             NaN              NaN
# 2668            NaN             NaN             NaN              NaN
# 2669            NaN             NaN             NaN              NaN
# 2670            NaN             NaN             NaN              NaN
#
#       industry_income_score  international_outlook_score  \
# 1907                    NaN                          NaN
# 1908                    NaN                          NaN
# 1909                    NaN                          NaN
# 1910                    NaN                          NaN
# 1911                    NaN                          NaN
# ...                     ...                          ...
# 2666                    NaN                          NaN
# 2667                    NaN                          NaN
# 2668                    NaN                          NaN
# 2669                    NaN                          NaN
# 2670                    NaN                          NaN
#
#                                                 address  street_address  \
# 1907          13 Dostyk ave, Almaty, 050010, Kazakhstan             NaN
# 1908  BP 1252 Route de Batna, Khenchela, 40004, Algeria             NaN
# 1909  Capt Akaash Rabbani Shaheed Rd, Abbottabad Dis...             NaN
# 1910    BP N°26 RP, Mila, Mila Province, 43000, Algeria             NaN
# 1911  Barbaros Mahallesi, Erkilet Bulvarı, Kocasinan...             NaN
# ...                                                 ...             ...
# 2666         15 Zarqa, Zarqa, Zarqa Governorate, Jordan             NaN
# 2667  187a I.Zhansugurov Str., Taldykorgan, 040009, ...             NaN
# 2668     103, Chudnivska str., Zhytomyr, 10005, Ukraine             NaN
# 2669    P.O. Box 3117, Djelfa, Djelfa Province, Algeria             NaN
# 2670  4/B Block 6, Saharah-e-Ghalib, Karachi, Sindh,...             NaN
#
#       locality_address  region_address  postcode_address  country_address
# 1907               NaN             NaN               NaN              NaN
# 1908               NaN             NaN               NaN              NaN
# 1909               NaN             NaN               NaN              NaN
# 1910               NaN             NaN               NaN              NaN
# 1911               NaN             NaN               NaN              NaN
# ...                ...             ...               ...              ...
# 2666               NaN             NaN               NaN              NaN
# 2667               NaN             NaN               NaN              NaN
# 2668               NaN             NaN               NaN              NaN
# 2669               NaN             NaN               NaN              NaN
# 2670               NaN             NaN               NaN              NaN
#
# [764 rows x 18 columns]

# %%
df[df['rank'] == 'Reporter']
# Out:
#           rank                                             name  \
# 1907  Reporter      Abai Kazakh National Pedagogical University
# 1908  Reporter           Abbes Laghrour University of Khenchala
# 1909  Reporter  Abbottabad University of Science and Technology
# 1910  Reporter    Abdelhafid Boussouf University Center of Mila
# 1911  Reporter                          Abdullah Gül University
# ...        ...                                              ...
# 2666  Reporter                                 Zarqa University
# 2667  Reporter                               Zhetysu University
# 2668  Reporter            Zhytomyr Polytechnic State University
# 2669  Reporter                Ziane Achour University of Djelfa
# 2670  Reporter                              Ziauddin University
#
#       number_students  student_staff_ratio  intl_students  female_male_ratio  \
# 1907            16862               16.100          3.000             59.000
# 1908            18085               26.100          0.000             70.000
# 1909             4200               13.300          0.000             31.000
# 1910            11027               24.900          0.000             72.000
# 1911             2944               22.500          9.000             46.000
# ...               ...                  ...            ...                ...
# 2666             5881               17.000         35.000             60.000
# 2667             4872               18.200          0.000             66.000
# 2668             4454               16.100          1.000             40.000
# 2669            31103               28.500          0.000             55.000
# 2670             5672                9.200          0.000             58.000
#
#       overall_score  teaching_score  research_score  citations_score  \
# 1907            NaN             NaN             NaN              NaN
# 1908            NaN             NaN             NaN              NaN
# 1909            NaN             NaN             NaN              NaN
# 1910            NaN             NaN             NaN              NaN
# 1911            NaN             NaN             NaN              NaN
# ...             ...             ...             ...              ...
# 2666            NaN             NaN             NaN              NaN
# 2667            NaN             NaN             NaN              NaN
# 2668            NaN             NaN             NaN              NaN
# 2669            NaN             NaN             NaN              NaN
# 2670            NaN             NaN             NaN              NaN
#
#       industry_income_score  international_outlook_score  \
# 1907                    NaN                          NaN
# 1908                    NaN                          NaN
# 1909                    NaN                          NaN
# 1910                    NaN                          NaN
# 1911                    NaN                          NaN
# ...                     ...                          ...
# 2666                    NaN                          NaN
# 2667                    NaN                          NaN
# 2668                    NaN                          NaN
# 2669                    NaN                          NaN
# 2670                    NaN                          NaN
#
#                                                 address  street_address  \
# 1907          13 Dostyk ave, Almaty, 050010, Kazakhstan             NaN
# 1908  BP 1252 Route de Batna, Khenchela, 40004, Algeria             NaN
# 1909  Capt Akaash Rabbani Shaheed Rd, Abbottabad Dis...             NaN
# 1910    BP N°26 RP, Mila, Mila Province, 43000, Algeria             NaN
# 1911  Barbaros Mahallesi, Erkilet Bulvarı, Kocasinan...             NaN
# ...                                                 ...             ...
# 2666         15 Zarqa, Zarqa, Zarqa Governorate, Jordan             NaN
# 2667  187a I.Zhansugurov Str., Taldykorgan, 040009, ...             NaN
# 2668     103, Chudnivska str., Zhytomyr, 10005, Ukraine             NaN
# 2669    P.O. Box 3117, Djelfa, Djelfa Province, Algeria             NaN
# 2670  4/B Block 6, Saharah-e-Ghalib, Karachi, Sindh,...             NaN
#
#       locality_address  region_address  postcode_address  country_address
# 1907               NaN             NaN               NaN              NaN
# 1908               NaN             NaN               NaN              NaN
# 1909               NaN             NaN               NaN              NaN
# 1910               NaN             NaN               NaN              NaN
# 1911               NaN             NaN               NaN              NaN
# ...                ...             ...               ...              ...
# 2666               NaN             NaN               NaN              NaN
# 2667               NaN             NaN               NaN              NaN
# 2668               NaN             NaN               NaN              NaN
# 2669               NaN             NaN               NaN              NaN
# 2670               NaN             NaN               NaN              NaN
#
# [764 rows x 18 columns]

# %%
df.loc[df['rank'] == 'Reporter', 'overall_score'] = df.loc[df['rank'] == 'Reporter', 'overall_score'].fillna(0)

# %%
df[df['rank'] == 'Reporter'].iloc[:, [0,6]]
# Out:
#           rank  overall_score
# 1907  Reporter          0.000
# 1908  Reporter          0.000
# 1909  Reporter          0.000
# 1910  Reporter          0.000
# 1911  Reporter          0.000
# ...        ...            ...
# 2666  Reporter          0.000
# 2667  Reporter          0.000
# 2668  Reporter          0.000
# 2669  Reporter          0.000
# 2670  Reporter          0.000
#
# [764 rows x 2 columns]

# %%
df.isna().sum()
# Out:
# rank                              0
# name                              0
# number_students                   0
# student_staff_ratio               0
# intl_students                     0
# female_male_ratio                 0
# overall_score                     0
# teaching_score                  764
# research_score                  764
# citations_score                 764
# industry_income_score           764
# international_outlook_score     764
# address                         194
# street_address                 2671
# locality_address               2671
# region_address                 2671
# postcode_address               2671
# country_address                2671
# dtype: int64

# %% [markdown]
# ### "teaching_score"

# %%
df[df['rank'] == 'Reporter'].iloc[:, [0,7]]
# Out:
#           rank  teaching_score
# 1907  Reporter             NaN
# 1908  Reporter             NaN
# 1909  Reporter             NaN
# 1910  Reporter             NaN
# 1911  Reporter             NaN
# ...        ...             ...
# 2666  Reporter             NaN
# 2667  Reporter             NaN
# 2668  Reporter             NaN
# 2669  Reporter             NaN
# 2670  Reporter             NaN
#
# [764 rows x 2 columns]

# %%
df.loc[df['rank'] == 'Reporter', 'teaching_score'] = df.loc[df['rank'] == 'Reporter', 'teaching_score'].fillna(0)

# %%
df[df['rank'] == 'Reporter'].iloc[:, [0,7]]
# Out:
#           rank  teaching_score
# 1907  Reporter           0.000
# 1908  Reporter           0.000
# 1909  Reporter           0.000
# 1910  Reporter           0.000
# 1911  Reporter           0.000
# ...        ...             ...
# 2666  Reporter           0.000
# 2667  Reporter           0.000
# 2668  Reporter           0.000
# 2669  Reporter           0.000
# 2670  Reporter           0.000
#
# [764 rows x 2 columns]

# %% [markdown]
# ### 'research_score' & 'citations_score' & 'industry_income_score' & 'international_outlook_score'

# %%
df.isna().sum()
# Out:
# rank                              0
# name                              0
# number_students                   0
# student_staff_ratio               0
# intl_students                     0
# female_male_ratio                 0
# overall_score                     0
# teaching_score                    0
# research_score                  764
# citations_score                 764
# industry_income_score           764
# international_outlook_score     764
# address                         194
# street_address                 2671
# locality_address               2671
# region_address                 2671
# postcode_address               2671
# country_address                2671
# dtype: int64

# %%
df.loc[df['rank'] == 'Reporter', 'research_score'] = df.loc[df['rank'] == 'Reporter', 'research_score'].fillna(0)
df.loc[df['rank'] == 'Reporter', 'citations_score'] = df.loc[df['rank'] == 'Reporter', 'citations_score'].fillna(0)
df.loc[df['rank'] == 'Reporter', 'industry_income_score'] = df.loc[df['rank'] == 'Reporter', 'industry_income_score'].fillna(0)
df.loc[df['rank'] == 'Reporter', 'international_outlook_score'] = df.loc[df['rank'] == 'Reporter', 'international_outlook_score'].fillna(0)

# %%
df.isna().sum()
# Out:
# rank                              0
# name                              0
# number_students                   0
# student_staff_ratio               0
# intl_students                     0
# female_male_ratio                 0
# overall_score                     0
# teaching_score                    0
# research_score                    0
# citations_score                   0
# industry_income_score             0
# international_outlook_score       0
# address                         194
# street_address                 2671
# locality_address               2671
# region_address                 2671
# postcode_address               2671
# country_address                2671
# dtype: int64

# %%
df.address.head()
# Out:
# 0    University Offices, Wellington Square, Oxford,...
# 1    450 Jane Stanford Way, Stanford, California, 9...
# 2    77 Massachusetts Avenue, Cambridge, Massachuse...
# 3    Massachusetts Hall, Cambridge, Massachusetts, ...
# 4    The Old Schools, Trinity Lane, Cambridge, Camb...
# Name: address, dtype: object

# %%
df[(df["rank"] == 'Reporter') & (df["address"].isnull())].iloc[:, [0,12]]
# Out:
#           rank address
# 1956  Reporter     NaN
# 2018  Reporter     NaN
# 2023  Reporter     NaN
# 2024  Reporter     NaN
# 2081  Reporter     NaN
# 2169  Reporter     NaN
# 2179  Reporter     NaN
# 2228  Reporter     NaN
# 2265  Reporter     NaN
# 2276  Reporter     NaN
# 2296  Reporter     NaN
# 2304  Reporter     NaN
# 2369  Reporter     NaN
# 2370  Reporter     NaN
# 2371  Reporter     NaN
# 2421  Reporter     NaN
# 2429  Reporter     NaN
# 2434  Reporter     NaN
# 2435  Reporter     NaN
# 2456  Reporter     NaN
# 2468  Reporter     NaN
# 2481  Reporter     NaN
# 2491  Reporter     NaN
# 2492  Reporter     NaN
# 2493  Reporter     NaN
# 2497  Reporter     NaN
# 2501  Reporter     NaN
# 2532  Reporter     NaN
# 2543  Reporter     NaN
# 2605  Reporter     NaN
# 2613  Reporter     NaN
# 2618  Reporter     NaN
# 2619  Reporter     NaN
# 2624  Reporter     NaN
# 2625  Reporter     NaN
# 2643  Reporter     NaN
# 2662  Reporter     NaN

# %%
df.loc[df['rank'] == 'Reporter','address']
# Out:
# 1907            13 Dostyk ave, Almaty, 050010, Kazakhstan
# 1908    BP 1252 Route de Batna, Khenchela, 40004, Algeria
# 1909    Capt Akaash Rabbani Shaheed Rd, Abbottabad Dis...
# 1910      BP N°26 RP, Mila, Mila Province, 43000, Algeria
# 1911    Barbaros Mahallesi, Erkilet Bulvarı, Kocasinan...
#                               ...
# 2666           15 Zarqa, Zarqa, Zarqa Governorate, Jordan
# 2667    187a I.Zhansugurov Str., Taldykorgan, 040009, ...
# 2668       103, Chudnivska str., Zhytomyr, 10005, Ukraine
# 2669      P.O. Box 3117, Djelfa, Djelfa Province, Algeria
# 2670    4/B Block 6, Saharah-e-Ghalib, Karachi, Sindh,...
# Name: address, Length: 764, dtype: object

# %%
df['address'] = df['address'].astype(str)

# %%
def get_country(address):
    if pd.isna(address):
        return None
    return address.split(',')[-1].strip()

# %%
df['country'] = df['address'].apply(get_country)

# %%
df.iloc[:, [12,13]]
# Out:
#                                                 address         country
# 0     University Offices, Wellington Square, Oxford,...  United Kingdom
# 1     450 Jane Stanford Way, Stanford, California, 9...   United States
# 2     77 Massachusetts Avenue, Cambridge, Massachuse...   United States
# 3     Massachusetts Hall, Cambridge, Massachusetts, ...   United States
# 4     The Old Schools, Trinity Lane, Cambridge, Camb...  United Kingdom
# ...                                                 ...             ...
# 2666         15 Zarqa, Zarqa, Zarqa Governorate, Jordan          Jordan
# 2667  187a I.Zhansugurov Str., Taldykorgan, 040009, ...      Kazakhstan
# 2668     103, Chudnivska str., Zhytomyr, 10005, Ukraine         Ukraine
# 2669    P.O. Box 3117, Djelfa, Djelfa Province, Algeria         Algeria
# 2670  4/B Block 6, Saharah-e-Ghalib, Karachi, Sindh,...        Pakistan
#
# [2671 rows x 2 columns]

# %%
df['country'].value_counts()
# Out:
# country
# nan               194
# United States     175
# Japan             169
# United Kingdom    164
# India             122
#                  ...
# Mauritius           1
# Mozambique          1
# Jamaica             1
# Fiji                1
# 10000               1
# Name: count, Length: 124, dtype: int64

# %%
df[(df['country'] == '10000')].iloc[:,[0,1,12,13]]
# Out:
#           rank name                           address country
# 2615  Reporter  UBT  Lagija Kalabria, Pristina, 10000   10000

# %%
df.loc[df["country"] == '10000', 'country'] = 'Kosova'

# %%
df[(df['country'] == 'Kosova')].iloc[:,[0,1,12,13]]
# Out:
#           rank name                           address country
# 2615  Reporter  UBT  Lagija Kalabria, Pristina, 10000  Kosova

# %%
df[df['country'] == 'nan'].count()
# Out:
# rank                           194
# name                           194
# number_students                194
# student_staff_ratio            194
# intl_students                  194
# female_male_ratio              194
# overall_score                  194
# teaching_score                 194
# research_score                 194
# citations_score                194
# industry_income_score          194
# international_outlook_score    194
# address                        194
# country                        194
# dtype: int64

# %%
df[(df["country"] == 'nan')].iloc[:, [0,1,12,13]]
# Out:
#           rank                            name address country
# 20          21           University of Toronto     nan     nan
# 36          37         University of Melbourne     nan     nan
# 40          41  University of British Columbia     nan     nan
# 48          49               McGill University     nan     nan
# 53          54               Monash University     nan     nan
# ...        ...                             ...     ...     ...
# 2619  Reporter               Russia University     nan     nan
# 2624  Reporter               Russia University     nan     nan
# 2625  Reporter               Russia University     nan     nan
# 2643  Reporter               Russia University     nan     nan
# 2662  Reporter               Russia University     nan     nan
#
# [194 rows x 4 columns]

# %%
df.drop(columns = ['address'], inplace=True)

# %%
df
# Out:
#           rank                                   name  number_students  \
# 0            1                   University of Oxford            21750
# 1            2                    Stanford University            14517
# 2            3  Massachusetts Institute of Technology            11085
# 3            4                     Harvard University            20050
# 4            5                University of Cambridge            20565
# ...        ...                                    ...              ...
# 2666  Reporter                       Zarqa University             5881
# 2667  Reporter                     Zhetysu University             4872
# 2668  Reporter  Zhytomyr Polytechnic State University             4454
# 2669  Reporter      Ziane Achour University of Djelfa            31103
# 2670  Reporter                    Ziauddin University             5672
#
#       student_staff_ratio  intl_students  female_male_ratio  overall_score  \
# 0                  10.900         42.000             49.000         98.500
# 1                   6.400         23.000             47.000         98.000
# 2                   8.000         33.000             41.000         97.900
# 3                   9.000         25.000             51.000         97.800
# 4                  11.500         38.000             48.000         97.500
# ...                   ...            ...                ...            ...
# 2666               17.000         35.000             60.000          0.000
# 2667               18.200          0.000             66.000          0.000
# 2668               16.100          1.000             40.000          0.000
# 2669               28.500          0.000             55.000          0.000
# 2670                9.200          0.000             58.000          0.000
#
#       teaching_score  research_score  citations_score  industry_income_score  \
# 0             96.600         100.000           99.000                 98.700
# 1             99.000          97.800           99.600                100.000
# 2             98.600          96.200           99.700                100.000
# 3             97.700          99.900           99.400                 84.200
# 4             95.800         100.000           98.000                 87.900
# ...              ...             ...              ...                    ...
# 2666           0.000           0.000            0.000                  0.000
# 2667           0.000           0.000            0.000                  0.000
# 2668           0.000           0.000            0.000                  0.000
# 2669           0.000           0.000            0.000                  0.000
# 2670           0.000           0.000            0.000                  0.000
#
#       international_outlook_score         country
# 0                          97.500  United Kingdom
# 1                          87.000   United States
# 2                          93.800   United States
# 3                          90.800   United States
# 4                          97.400  United Kingdom
# ...                           ...             ...
# 2666                        0.000          Jordan
# 2667                        0.000      Kazakhstan
# 2668                        0.000         Ukraine
# 2669                        0.000         Algeria
# 2670                        0.000        Pakistan
#
# [2671 rows x 13 columns]

# %%
df[(df['name'] == 'Russia University')]
# Out:
#           rank               name  number_students  student_staff_ratio  \
# 94         =95  Russia University            32680                9.600
# 224        201  Russia University             6111               11.600
# 386        351  Russia University            16400               10.000
# 406        401  Russia University            16061                6.600
# 436        401  Russia University            34656               18.600
# ...        ...                ...              ...                  ...
# 2619  Reporter  Russia University             6412               16.600
# 2624  Reporter  Russia University             3831                8.700
# 2625  Reporter  Russia University             7720               14.200
# 2643  Reporter  Russia University             6524                5.900
# 2662  Reporter  Russia University            10900               15.700
#
#       intl_students  female_male_ratio  overall_score  teaching_score  \
# 94           37.000             50.000         67.000          87.500
# 224          21.000             50.405         58.600          63.500
# 386          33.000             42.000         51.000          43.400
# 406          18.000             42.000         49.000          71.700
# 436          12.000             50.405         49.000          34.400
# ...             ...                ...            ...             ...
# 2619          8.000             33.000          0.000           0.000
# 2624          8.000             52.000          0.000           0.000
# 2625         10.000             78.000          0.000           0.000
# 2643         32.000             66.000          0.000           0.000
# 2662         10.000             57.000          0.000           0.000
#
#       research_score  citations_score  industry_income_score  \
# 94            75.200           33.900                 91.100
# 224           48.800           55.100                 68.600
# 386           31.300           67.400                 61.600
# 406           43.900           22.100                 51.700
# 436           44.000           57.300                 56.500
# ...              ...              ...                    ...
# 2619           0.000            0.000                  0.000
# 2624           0.000            0.000                  0.000
# 2625           0.000            0.000                  0.000
# 2643           0.000            0.000                  0.000
# 2662           0.000            0.000                  0.000
#
#       international_outlook_score country
# 94                         73.800  Russia
# 224                        72.700  Russia
# 386                        65.200  Russia
# 406                        59.300  Russia
# 436                        51.400  Russia
# ...                           ...     ...
# 2619                        0.000  Russia
# 2624                        0.000  Russia
# 2625                        0.000  Russia
# 2643                        0.000  Russia
# 2662                        0.000  Russia
#
# [116 rows x 13 columns]

# %%
df.loc[df["name"] == 'Russia University', 'country'].replace('nan', 'Russia')
# Out:
# 94      Russia
# 224     Russia
# 386     Russia
# 406     Russia
# 436     Russia
#          ...
# 2619    Russia
# 2624    Russia
# 2625    Russia
# 2643    Russia
# 2662    Russia
# Name: country, Length: 116, dtype: object

# %%
df.loc[df['name'] == 'Russia University', 'country'] = 'Russia'

# %%
df.loc[df['name'] == 'Russia University']
# Out:
#           rank               name  number_students  student_staff_ratio  \
# 94         =95  Russia University            32680                9.600
# 224        201  Russia University             6111               11.600
# 386        351  Russia University            16400               10.000
# 406        401  Russia University            16061                6.600
# 436        401  Russia University            34656               18.600
# ...        ...                ...              ...                  ...
# 2619  Reporter  Russia University             6412               16.600
# 2624  Reporter  Russia University             3831                8.700
# 2625  Reporter  Russia University             7720               14.200
# 2643  Reporter  Russia University             6524                5.900
# 2662  Reporter  Russia University            10900               15.700
#
#       intl_students  female_male_ratio  overall_score  teaching_score  \
# 94           37.000             50.000         67.000          87.500
# 224          21.000             50.405         58.600          63.500
# 386          33.000             42.000         51.000          43.400
# 406          18.000             42.000         49.000          71.700
# 436          12.000             50.405         49.000          34.400
# ...             ...                ...            ...             ...
# 2619          8.000             33.000          0.000           0.000
# 2624          8.000             52.000          0.000           0.000
# 2625         10.000             78.000          0.000           0.000
# 2643         32.000             66.000          0.000           0.000
# 2662         10.000             57.000          0.000           0.000
#
#       research_score  citations_score  industry_income_score  \
# 94            75.200           33.900                 91.100
# 224           48.800           55.100                 68.600
# 386           31.300           67.400                 61.600
# 406           43.900           22.100                 51.700
# 436           44.000           57.300                 56.500
# ...              ...              ...                    ...
# 2619           0.000            0.000                  0.000
# 2624           0.000            0.000                  0.000
# 2625           0.000            0.000                  0.000
# 2643           0.000            0.000                  0.000
# 2662           0.000            0.000                  0.000
#
#       international_outlook_score address country
# 94                         73.800     nan  Russia
# 224                        72.700     nan  Russia
# 386                        65.200     nan  Russia
# 406                        59.300     nan  Russia
# 436                        51.400     nan  Russia
# ...                           ...     ...     ...
# 2619                        0.000     nan  Russia
# 2624                        0.000     nan  Russia
# 2625                        0.000     nan  Russia
# 2643                        0.000     nan  Russia
# 2662                        0.000     nan  Russia
#
# [116 rows x 14 columns]

# %%
df[df['country'] == 'nan']
# Out:
#           rank                                            name  \
# 20          21                           University of Toronto
# 36          37                         University of Melbourne
# 40          41                  University of British Columbia
# 48          49                               McGill University
# 53          54                               Monash University
# ...        ...                                             ...
# 937        801  University of Northern British Columbia (UNBC)
# 954        801                            University of Regina
# 1177      1001                 Technological University Dublin
# 1334      1201                        University of Lethbridge
# 2296  Reporter                        Kohsar University Murree
#
#       number_students  student_staff_ratio  intl_students  female_male_ratio  \
# 20              79282               25.800         27.000             56.000
# 36              51307               25.100         47.000             58.000
# 40              58987               19.400         34.000             55.000
# 48              30821               11.900         29.000             61.000
# 53              58460               43.100         38.000             56.000
# ...               ...                  ...            ...                ...
# 937              2937               16.500         12.000             61.000
# 954             14167               24.600         26.000             49.000
# 1177            20801               18.700         18.000             44.000
# 1334             7181               13.400         12.000             50.405
# 2296              760               24.500          0.000             69.000
#
#       overall_score  teaching_score  research_score  citations_score  \
# 20           88.600          77.500          94.100           92.800
# 36           79.200          64.800          76.400           90.100
# 40           78.000          62.500          76.600           90.500
# 48           76.000          62.300          72.300           88.800
# 53           75.200          55.300          67.800           94.700
# ...             ...             ...             ...              ...
# 937          36.900          21.100          21.800           51.700
# 954          36.900          17.800          19.500           62.900
# 1177         32.600          19.100          13.100           45.600
# 1334         28.200          20.300          14.100           31.200
# 2296          0.000           0.000           0.000            0.000
#
#       industry_income_score  international_outlook_score address country
# 20                   96.100                       90.700     nan     nan
# 36                   98.300                       92.700     nan     nan
# 40                   76.700                       95.000     nan     nan
# 48                   76.100                       92.500     nan     nan
# 53                   99.700                       91.100     nan     nan
# ...                     ...                          ...     ...     ...
# 937                  21.400                       52.000     nan     nan
# 954                  36.100                       71.000     nan     nan
# 1177                 66.000                       64.900     nan     nan
# 1334                 34.600                       61.400     nan     nan
# 2296                  0.000                        0.000     nan     nan
#
# [78 rows x 14 columns]

# %%
df.loc[df['country'] == '', 'country'] = 'Null'

# %%
df[df['country'] == 'Null']
# Out:
#           rank                                            name  \
# 20          21                           University of Toronto
# 36          37                         University of Melbourne
# 40          41                  University of British Columbia
# 48          49                               McGill University
# 53          54                               Monash University
# ...        ...                                             ...
# 937        801  University of Northern British Columbia (UNBC)
# 954        801                            University of Regina
# 1177      1001                 Technological University Dublin
# 1334      1201                        University of Lethbridge
# 2296  Reporter                        Kohsar University Murree
#
#       number_students  student_staff_ratio  intl_students  female_male_ratio  \
# 20              79282               25.800         27.000             56.000
# 36              51307               25.100         47.000             58.000
# 40              58987               19.400         34.000             55.000
# 48              30821               11.900         29.000             61.000
# 53              58460               43.100         38.000             56.000
# ...               ...                  ...            ...                ...
# 937              2937               16.500         12.000             61.000
# 954             14167               24.600         26.000             49.000
# 1177            20801               18.700         18.000             44.000
# 1334             7181               13.400         12.000             50.405
# 2296              760               24.500          0.000             69.000
#
#       overall_score  teaching_score  research_score  citations_score  \
# 20           88.600          77.500          94.100           92.800
# 36           79.200          64.800          76.400           90.100
# 40           78.000          62.500          76.600           90.500
# 48           76.000          62.300          72.300           88.800
# 53           75.200          55.300          67.800           94.700
# ...             ...             ...             ...              ...
# 937          36.900          21.100          21.800           51.700
# 954          36.900          17.800          19.500           62.900
# 1177         32.600          19.100          13.100           45.600
# 1334         28.200          20.300          14.100           31.200
# 2296          0.000           0.000           0.000            0.000
#
#       industry_income_score  international_outlook_score country
# 20                   96.100                       90.700    Null
# 36                   98.300                       92.700    Null
# 40                   76.700                       95.000    Null
# 48                   76.100                       92.500    Null
# 53                   99.700                       91.100    Null
# ...                     ...                          ...     ...
# 937                  21.400                       52.000    Null
# 954                  36.100                       71.000    Null
# 1177                 66.000                       64.900    Null
# 1334                 34.600                       61.400    Null
# 2296                  0.000                        0.000    Null
#
# [78 rows x 13 columns]

# %%
df
# Out:
#           rank                                   name  number_students  \
# 0            1                   University of Oxford            21750
# 1            2                    Stanford University            14517
# 2            3  Massachusetts Institute of Technology            11085
# 3            4                     Harvard University            20050
# 4            5                University of Cambridge            20565
# ...        ...                                    ...              ...
# 2666  Reporter                       Zarqa University             5881
# 2667  Reporter                     Zhetysu University             4872
# 2668  Reporter  Zhytomyr Polytechnic State University             4454
# 2669  Reporter      Ziane Achour University of Djelfa            31103
# 2670  Reporter                    Ziauddin University             5672
#
#       student_staff_ratio  intl_students  female_male_ratio  overall_score  \
# 0                  10.900         42.000             49.000         98.500
# 1                   6.400         23.000             47.000         98.000
# 2                   8.000         33.000             41.000         97.900
# 3                   9.000         25.000             51.000         97.800
# 4                  11.500         38.000             48.000         97.500
# ...                   ...            ...                ...            ...
# 2666               17.000         35.000             60.000          0.000
# 2667               18.200          0.000             66.000          0.000
# 2668               16.100          1.000             40.000          0.000
# 2669               28.500          0.000             55.000          0.000
# 2670                9.200          0.000             58.000          0.000
#
#       teaching_score  research_score  citations_score  industry_income_score  \
# 0             96.600         100.000           99.000                 98.700
# 1             99.000          97.800           99.600                100.000
# 2             98.600          96.200           99.700                100.000
# 3             97.700          99.900           99.400                 84.200
# 4             95.800         100.000           98.000                 87.900
# ...              ...             ...              ...                    ...
# 2666           0.000           0.000            0.000                  0.000
# 2667           0.000           0.000            0.000                  0.000
# 2668           0.000           0.000            0.000                  0.000
# 2669           0.000           0.000            0.000                  0.000
# 2670           0.000           0.000            0.000                  0.000
#
#       international_outlook_score         country
# 0                          97.500  United Kingdom
# 1                          87.000   United States
# 2                          93.800   United States
# 3                          90.800   United States
# 4                          97.400  United Kingdom
# ...                           ...             ...
# 2666                        0.000          Jordan
# 2667                        0.000      Kazakhstan
# 2668                        0.000         Ukraine
# 2669                        0.000         Algeria
# 2670                        0.000        Pakistan
#
# [2671 rows x 13 columns]

# %%
df['Numerical Rank'] = range(1, len(df2) + 1)

# %%
df.head(50)
# Out:
#    rank                                               name  number_students  \
# 0     1                               University of Oxford            21750
# 1     2                                Stanford University            14517
# 2     3              Massachusetts Institute of Technology            11085
# 3     4                                 Harvard University            20050
# 4     5                            University of Cambridge            20565
# 5     6                               Princeton University             7753
# 6     7                 California Institute of Technology             2240
# 7     8                            Imperial College London            20275
# 8     9                 University of California, Berkeley            39991
# 9    10                                    Yale University            11924
# 10   11                                         ETH Zurich            22619
# 11   12                                Tsinghua University            38518
# 12   13                          The University of Chicago            15792
# 13   14                                  Peking University            33064
# 14   15                           Johns Hopkins University            15772
# 15   16                         University of Pennsylvania            21312
# 16   17                                Columbia University            25914
# 17   18              University of California, Los Angeles            42634
# 18   19                   National University of Singapore            33334
# 19   20                                 Cornell University            23620
# 20   21                              University of Toronto            79282
# 21   22                                                UCL            41110
# 22   23                   University of Michigan-Ann Arbor            45783
# 23   24                         Carnegie Mellon University            13562
# 24   25                           University of Washington            49486
# 25   26                                    Duke University            15527
# 26   27                                New York University            48461
# 27   28                            Northwestern University            18894
# 28   29                            The University of Tokyo            26345
# 29  =30                            University of Edinburgh            33940
# 30  =30                     Technical University of Munich            35506
# 31   32        Nanyang Technological University, Singapore            25895
# 32   33           École Polytechnique Fédérale de Lausanne            12543
# 33   34                University of California, San Diego            40596
# 34   35                            University of Hong Kong            18103
# 35   36                    Georgia Institute of Technology            32079
# 36   37                            University of Melbourne            51307
# 37  =38                              King’s College London            32835
# 38  =38                                         LMU Munich            34622
# 39   40  Paris Sciences et Lettres – PSL Research Unive...            16120
# 40   41                     University of British Columbia            58987
# 41   42         University of Illinois at Urbana-Champaign            50250
# 42   43                      Shanghai Jiao Tong University            38472
# 43   44                                   Fudan University            38101
# 44   45                                          KU Leuven            49435
# 45   46   London School of Economics and Political Science            11945
# 46   47                             Universität Heidelberg            19315
# 47   48                     Delft University of Technology            21262
# 48   49                                  McGill University            30821
# 49   50                               Karolinska Institute             8085
#
#     student_staff_ratio  intl_students  female_male_ratio  overall_score  \
# 0                10.900         42.000             49.000         98.500
# 1                 6.400         23.000             47.000         98.000
# 2                 8.000         33.000             41.000         97.900
# 3                 9.000         25.000             51.000         97.800
# 4                11.500         38.000             48.000         97.500
# 5                 7.300         23.000             47.000         96.900
# 6                 6.100         33.000             37.000         96.500
# 7                11.800         61.000             42.000         95.100
# 8                17.900         22.000             52.000         94.600
# 9                 5.200         21.000             51.000         94.200
# 10               15.400         43.000             33.000         93.100
# 11               11.200         10.000             50.405         92.400
# 12                6.200         36.000             47.000         92.100
# 13               10.900         14.000             50.405         91.800
# 14                4.100         28.000             56.000         91.100
# 15                6.200         22.000             54.000         91.000
# 16                5.200         35.000             50.405         90.900
# 17                9.600         15.000             56.000         90.100
# 18               20.000         24.000             49.000         90.000
# 19               10.000         24.000             51.000         89.500
# 20               25.800         27.000             56.000         88.600
# 21               11.300         61.000             59.000         88.100
# 22                8.100         16.000             51.000         87.400
# 23               11.900         44.000             44.000         86.300
# 24               10.100         16.000             56.000         85.300
# 25                3.900         18.000             52.000         83.900
# 26               11.800         42.000             58.000         83.500
# 27               13.100         18.000             52.000         83.200
# 28               10.300         15.000             50.405         83.100
# 29               11.500         46.000             61.000         82.500
# 30               44.400         39.000             37.000         82.500
# 31               16.700         27.000             49.000         82.300
# 32               13.500         64.000             30.000         81.400
# 33               12.000         19.000             45.000         81.000
# 34               18.300         43.000             55.000         80.300
# 35               28.000         29.000             34.000         80.000
# 36               25.100         47.000             58.000         79.200
# 37               13.900         53.000             63.000         79.000
# 38               33.500         18.000             62.000         79.000
# 39               15.000         22.000             51.000         78.500
# 40               19.400         34.000             55.000         78.000
# 41               19.600         23.000             51.000         77.900
# 42               12.600          9.000             37.000         77.700
# 43               12.600          9.000             52.000         77.500
# 44               37.300         19.000             52.000         77.000
# 45               12.600         72.000             56.000         76.800
# 46               13.300         20.000             55.000         76.700
# 47               15.900         30.000             31.000         76.300
# 48               11.900         29.000             61.000         76.000
# 49                9.900         27.000             70.000         75.900
#
#     teaching_score  research_score  citations_score  industry_income_score  \
# 0           96.600         100.000           99.000                 98.700
# 1           99.000          97.800           99.600                100.000
# 2           98.600          96.200           99.700                100.000
# 3           97.700          99.900           99.400                 84.200
# 4           95.800         100.000           98.000                 87.900
# 5           96.300          97.900           98.800                 95.100
# 6           96.600          98.000           95.900                100.000
# 7           90.900          95.500           98.600                 90.900
# 8           87.200          98.800           99.000                 99.400
# 9           94.000          94.900           97.700                 86.500
# 10          87.600          96.800           95.600                 82.900
# 11          95.300          98.100           93.200                 99.900
# 12          89.600          91.200           97.600                 93.800
# 13          95.600          97.300           87.200                 98.800
# 14          84.400          92.300           97.200                100.000
# 15          87.700          89.700           97.600                 97.700
# 16          88.600          89.700           97.400                 75.200
# 17          85.700          91.900           96.400                 92.300
# 18          78.800          94.000           95.400                100.000
# 19          85.700          88.700           97.600                 69.400
# 20          77.500          94.100           92.800                 96.100
# 21          78.400          86.400           98.600                 75.200
# 22          84.700          87.400           95.500                 80.700
# 23          75.000          84.600           98.900                 87.300
# 24          78.000          83.500           98.200                 77.600
# 25          79.300          76.100           96.200                100.000
# 26          73.200          84.000           94.900                 75.400
# 27          72.300          78.800           97.800                 99.700
# 28          93.900          94.200           67.800                100.000
# 29          70.700          77.500           96.900                 71.100
# 30          69.800          85.100           90.000                100.000
# 31          66.200          80.900           94.500                 99.700
# 32          74.500          73.200           90.300                 99.800
# 33          66.000          78.400           97.600                100.000
# 34          65.600          72.300           96.400                 95.200
# 35          63.400          78.900           94.100                 94.600
# 36          64.800          76.400           90.100                 98.300
# 37          59.800          75.100           97.700                 74.200
# 38          65.300          76.800           92.200                100.000
# 39          75.700          72.800           83.200                 99.700
# 40          62.500          76.600           90.500                 76.700
# 41          69.500          81.500           85.200                 85.300
# 42          76.600          82.500           75.400                100.000
# 43          76.500          75.300           83.500                 96.000
# 44          60.100          74.900           91.900                100.000
# 45          59.500          73.500           95.400                 55.900
# 46          67.700          64.300           94.600                 99.300
# 47          66.700          78.200           76.500                100.000
# 48          62.300          72.300           88.800                 76.100
# 49          58.900          67.900           95.300                 96.000
#
#     international_outlook_score         country  Numerical Rank
# 0                        97.500  United Kingdom               1
# 1                        87.000   United States               2
# 2                        93.800   United States               3
# 3                        90.800   United States               4
# 4                        97.400  United Kingdom               5
# 5                        89.100   United States               6
# 6                        90.600   United States               7
# 7                        98.300  United Kingdom               8
# 8                        86.800   United States               9
# 9                        82.400   United States              10
# 10                       95.600     Switzerland              11
# 11                       51.700           China              12
# 12                       82.300   United States              13
# 13                       70.200           China              14
# 14                       84.200   United States              15
# 15                       78.800   United States              16
# 16                       86.900   United States              17
# 17                       74.300   United States              18
# 18                       91.100       Singapore              19
# 19                       86.000   United States              20
# 20                       90.700            Null              21
# 21                       97.900  United Kingdom              22
# 22                       69.000   United States              23
# 23                       85.500   United States              24
# 24                       73.200   United States              25
# 25                       74.800   United States              26
# 26                       80.700   United States              27
# 27                       75.900   United States              28
# 28                       49.700           Japan              29
# 29                       97.000  United Kingdom              30
# 30                       83.100         Germany              31
# 31                       93.300       Singapore              32
# 32                       95.800     Switzerland              33
# 33                       74.300   United States              34
# 34                       96.800       Hong Kong              35
# 35                       84.800   United States              36
# 36                       92.700            Null              37
# 37                       97.500  United Kingdom              38
# 38                       76.900         Germany              39
# 39                       81.600          France              40
# 40                       95.000            Null              41
# 41                       64.000   United States              42
# 42                       60.600           China              43
# 43                       56.100           China              44
# 44                       79.600         Belgium              45
# 45                       94.100  United Kingdom              46
# 46                       76.400         Germany              47
# 47                       92.800     Netherlands              48
# 48                       92.500            Null              49
# 49                       85.700          Sweden              50

# %%
df[df['rank'] == 'Reporter']
# Out:
#           rank                                             name  \
# 1907  Reporter      Abai Kazakh National Pedagogical University
# 1908  Reporter           Abbes Laghrour University of Khenchala
# 1909  Reporter  Abbottabad University of Science and Technology
# 1910  Reporter    Abdelhafid Boussouf University Center of Mila
# 1911  Reporter                          Abdullah Gül University
# ...        ...                                              ...
# 2666  Reporter                                 Zarqa University
# 2667  Reporter                               Zhetysu University
# 2668  Reporter            Zhytomyr Polytechnic State University
# 2669  Reporter                Ziane Achour University of Djelfa
# 2670  Reporter                              Ziauddin University
#
#       number_students  student_staff_ratio  intl_students  female_male_ratio  \
# 1907            16862               16.100          3.000             59.000
# 1908            18085               26.100          0.000             70.000
# 1909             4200               13.300          0.000             31.000
# 1910            11027               24.900          0.000             72.000
# 1911             2944               22.500          9.000             46.000
# ...               ...                  ...            ...                ...
# 2666             5881               17.000         35.000             60.000
# 2667             4872               18.200          0.000             66.000
# 2668             4454               16.100          1.000             40.000
# 2669            31103               28.500          0.000             55.000
# 2670             5672                9.200          0.000             58.000
#
#       overall_score  teaching_score  research_score  citations_score  \
# 1907          0.000           0.000           0.000            0.000
# 1908          0.000           0.000           0.000            0.000
# 1909          0.000           0.000           0.000            0.000
# 1910          0.000           0.000           0.000            0.000
# 1911          0.000           0.000           0.000            0.000
# ...             ...             ...             ...              ...
# 2666          0.000           0.000           0.000            0.000
# 2667          0.000           0.000           0.000            0.000
# 2668          0.000           0.000           0.000            0.000
# 2669          0.000           0.000           0.000            0.000
# 2670          0.000           0.000           0.000            0.000
#
#       industry_income_score  international_outlook_score     country  \
# 1907                  0.000                        0.000  Kazakhstan
# 1908                  0.000                        0.000     Algeria
# 1909                  0.000                        0.000    Pakistan
# 1910                  0.000                        0.000     Algeria
# 1911                  0.000                        0.000      Turkey
# ...                     ...                          ...         ...
# 2666                  0.000                        0.000      Jordan
# 2667                  0.000                        0.000  Kazakhstan
# 2668                  0.000                        0.000     Ukraine
# 2669                  0.000                        0.000     Algeria
# 2670                  0.000                        0.000    Pakistan
#
#       Numerical Rank
# 1907            1908
# 1908            1909
# 1909            1910
# 1910            1911
# 1911            1912
# ...              ...
# 2666            2667
# 2667            2668
# 2668            2669
# 2669            2670
# 2670            2671
#
# [764 rows x 14 columns]

# %%
df.drop(columns = 'rank', inplace=True)

# %%
df.rename(columns={'name' : 'University Name', 
                   'Numerical Rank' : 'Rank'}, inplace=True)

# %%
df
# Out:
#                             University Name  number_students  \
# 0                      University of Oxford            21750
# 1                       Stanford University            14517
# 2     Massachusetts Institute of Technology            11085
# 3                        Harvard University            20050
# 4                   University of Cambridge            20565
# ...                                     ...              ...
# 2666                       Zarqa University             5881
# 2667                     Zhetysu University             4872
# 2668  Zhytomyr Polytechnic State University             4454
# 2669      Ziane Achour University of Djelfa            31103
# 2670                    Ziauddin University             5672
#
#       student_staff_ratio  intl_students  female_male_ratio  overall_score  \
# 0                  10.900         42.000             49.000         98.500
# 1                   6.400         23.000             47.000         98.000
# 2                   8.000         33.000             41.000         97.900
# 3                   9.000         25.000             51.000         97.800
# 4                  11.500         38.000             48.000         97.500
# ...                   ...            ...                ...            ...
# 2666               17.000         35.000             60.000          0.000
# 2667               18.200          0.000             66.000          0.000
# 2668               16.100          1.000             40.000          0.000
# 2669               28.500          0.000             55.000          0.000
# 2670                9.200          0.000             58.000          0.000
#
#       teaching_score  research_score  citations_score  industry_income_score  \
# 0             96.600         100.000           99.000                 98.700
# 1             99.000          97.800           99.600                100.000
# 2             98.600          96.200           99.700                100.000
# 3             97.700          99.900           99.400                 84.200
# 4             95.800         100.000           98.000                 87.900
# ...              ...             ...              ...                    ...
# 2666           0.000           0.000            0.000                  0.000
# 2667           0.000           0.000            0.000                  0.000
# 2668           0.000           0.000            0.000                  0.000
# 2669           0.000           0.000            0.000                  0.000
# 2670           0.000           0.000            0.000                  0.000
#
#       international_outlook_score         country  Rank
# 0                          97.500  United Kingdom     1
# 1                          87.000   United States     2
# 2                          93.800   United States     3
# 3                          90.800   United States     4
# 4                          97.400  United Kingdom     5
# ...                           ...             ...   ...
# 2666                        0.000          Jordan  2667
# 2667                        0.000      Kazakhstan  2668
# 2668                        0.000         Ukraine  2669
# 2669                        0.000         Algeria  2670
# 2670                        0.000        Pakistan  2671
#
# [2671 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['University Name', 'number_students', 'student_staff_ratio',
#        'intl_students', 'female_male_ratio', 'overall_score', 'teaching_score',
#        'research_score', 'citations_score', 'industry_income_score',
#        'international_outlook_score', 'country', 'Rank'],
#       dtype='object')

# %%
new_order = ['Rank', 'University Name', 'number_students', 'student_staff_ratio',
       'intl_students', 'female_male_ratio', 'overall_score', 'teaching_score',
       'research_score', 'citations_score', 'industry_income_score',
       'international_outlook_score', 'country']

# %%
df = df[new_order]

# %%
df
# Out:
#       Rank                        University Name  number_students  \
# 0        1                   University of Oxford            21750
# 1        2                    Stanford University            14517
# 2        3  Massachusetts Institute of Technology            11085
# 3        4                     Harvard University            20050
# 4        5                University of Cambridge            20565
# ...    ...                                    ...              ...
# 2666  2667                       Zarqa University             5881
# 2667  2668                     Zhetysu University             4872
# 2668  2669  Zhytomyr Polytechnic State University             4454
# 2669  2670      Ziane Achour University of Djelfa            31103
# 2670  2671                    Ziauddin University             5672
#
#       student_staff_ratio  intl_students  female_male_ratio  overall_score  \
# 0                  10.900         42.000             49.000         98.500
# 1                   6.400         23.000             47.000         98.000
# 2                   8.000         33.000             41.000         97.900
# 3                   9.000         25.000             51.000         97.800
# 4                  11.500         38.000             48.000         97.500
# ...                   ...            ...                ...            ...
# 2666               17.000         35.000             60.000          0.000
# 2667               18.200          0.000             66.000          0.000
# 2668               16.100          1.000             40.000          0.000
# 2669               28.500          0.000             55.000          0.000
# 2670                9.200          0.000             58.000          0.000
#
#       teaching_score  research_score  citations_score  industry_income_score  \
# 0             96.600         100.000           99.000                 98.700
# 1             99.000          97.800           99.600                100.000
# 2             98.600          96.200           99.700                100.000
# 3             97.700          99.900           99.400                 84.200
# 4             95.800         100.000           98.000                 87.900
# ...              ...             ...              ...                    ...
# 2666           0.000           0.000            0.000                  0.000
# 2667           0.000           0.000            0.000                  0.000
# 2668           0.000           0.000            0.000                  0.000
# 2669           0.000           0.000            0.000                  0.000
# 2670           0.000           0.000            0.000                  0.000
#
#       international_outlook_score         country
# 0                          97.500  United Kingdom
# 1                          87.000   United States
# 2                          93.800   United States
# 3                          90.800   United States
# 4                          97.400  United Kingdom
# ...                           ...             ...
# 2666                        0.000          Jordan
# 2667                        0.000      Kazakhstan
# 2668                        0.000         Ukraine
# 2669                        0.000         Algeria
# 2670                        0.000        Pakistan
#
# [2671 rows x 13 columns]

# %%
df[df['country'] == 'Null']
# Out:
#       Rank                                 University Name  number_students  \
# 20      21                           University of Toronto            79282
# 36      37                         University of Melbourne            51307
# 40      41                  University of British Columbia            58987
# 48      49                               McGill University            30821
# 53      54                               Monash University            58460
# ...    ...                                             ...              ...
# 937    938  University of Northern British Columbia (UNBC)             2937
# 954    955                            University of Regina            14167
# 1177  1178                 Technological University Dublin            20801
# 1334  1335                        University of Lethbridge             7181
# 2296  2297                        Kohsar University Murree              760
#
#       student_staff_ratio  intl_students  female_male_ratio  overall_score  \
# 20                 25.800         27.000             56.000         88.600
# 36                 25.100         47.000             58.000         79.200
# 40                 19.400         34.000             55.000         78.000
# 48                 11.900         29.000             61.000         76.000
# 53                 43.100         38.000             56.000         75.200
# ...                   ...            ...                ...            ...
# 937                16.500         12.000             61.000         36.900
# 954                24.600         26.000             49.000         36.900
# 1177               18.700         18.000             44.000         32.600
# 1334               13.400         12.000             50.405         28.200
# 2296               24.500          0.000             69.000          0.000
#
#       teaching_score  research_score  citations_score  industry_income_score  \
# 20            77.500          94.100           92.800                 96.100
# 36            64.800          76.400           90.100                 98.300
# 40            62.500          76.600           90.500                 76.700
# 48            62.300          72.300           88.800                 76.100
# 53            55.300          67.800           94.700                 99.700
# ...              ...             ...              ...                    ...
# 937           21.100          21.800           51.700                 21.400
# 954           17.800          19.500           62.900                 36.100
# 1177          19.100          13.100           45.600                 66.000
# 1334          20.300          14.100           31.200                 34.600
# 2296           0.000           0.000            0.000                  0.000
#
#       international_outlook_score country
# 20                         90.700    Null
# 36                         92.700    Null
# 40                         95.000    Null
# 48                         92.500    Null
# 53                         91.100    Null
# ...                           ...     ...
# 937                        52.000    Null
# 954                        71.000    Null
# 1177                       64.900    Null
# 1334                       61.400    Null
# 2296                        0.000    Null
#
# [78 rows x 13 columns]
